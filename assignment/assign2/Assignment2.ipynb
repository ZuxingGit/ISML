# %% [markdown]
# ## Q1
#
# **Primal Form:**
#
# The primal form of the hard-margin SVM is given by:
#
#  $$\min_{\mathbf{w},b} \frac{1}{2} \|\mathbf{w}\|^2,\quad &\text{s.t.}\quad & y_{i}(\mathbf{w}^{\top} \mathbf{x}_{i} + b) \geq 1, \quad i=1,2,...,N\\$$
#
#
#
# **Lagrangian:**
#
# We introduce Lagrange multipliers **α** to formulate the Lagrangian for this problem. The Lagrangian is given by:
#
# $$\mathcal{L} (\mathbf{w}, b, \alpha) = \frac{1}{2} \|\mathbf{w}\|^2 - \sum_{i=1}^{N}\alpha_{i}[y_{i}(\mathbf{w}^{\top} \mathbf{x}_{i} + b) - 1]$$
#
# where $\alpha_{i} \geq 0, i=1,...,N$ are the Lagrange multipliers.
#
#
#
# The objective is now:
#
# $$\min_{\mathbf{w}, b}  \max_{\alpha_{i} \geq 0} \mathcal{L}(\mathbf{w}, b, \alpha) = \min_{\mathbf{w}, b} \max_{\alpha_{i} \geq 0} \left( \frac{1}{2} \|\mathbf{w}\|^2 - \sum_{i=1}^{n} \alpha_i [y_i (\mathbf{w}^T \mathbf{x}_i + b) - 1] \right)$$
#
#
#
# **Simplify $$\mathcal{L} (\mathbf{w}, b, \alpha)$$:**
#
# $$\mathcal{L} (\mathbf{w}, b, \alpha) = \frac{1}{2} \|\mathbf{w}\|^2 - \sum_{i=1}^{N}\alpha_{i}[y_{i}(\mathbf{w}^{\top} \mathbf{x}_{i} + b) - 1]$$
#
# $$\quad\quad\quad\quad\quad = \frac{1}{2} \mathbf{w}^{\top}\mathbf{w} - \sum_{i=1}^{N}\alpha_{i}y_{i}\mathbf{w}^{\top} \mathbf{x}_{i} - \sum_{i=1}^{N}\alpha_{i}y_{i}b + \sum_{i=1}^{N}\alpha_{i}$$
#
# $$\quad\quad\quad\quad\quad = \frac{1}{2} \mathbf{w}^{\top}\mathbf{w} - \mathbf{w}^{\top}\sum_{i=1}^{N}\alpha_{i}y_{i} \mathbf{x}_{i} - \sum_{i=1}^{N}\alpha_{i}y_{i}b + \sum_{i=1}^{N}\alpha_{i}$$
#
#
#
# To find the optimal values for $$\mathbf{w}$$ and b, we differentiate the Lagrangian with respect to them and set the derivatives to zero:
#
# $$\frac{\partial\mathcal{L}}{\partial \mathbf{w}} = \mathbf{w} - \sum_{i=1}^{N} \alpha_i y_i \mathbf{x}_i = 0 \implies \mathbf{w} = \sum_{i=1}^{N} \alpha_i y_i \mathbf{x}_i$$
#
# $$\frac{\partial\mathcal{L}}{\partial b} = -\sum_{i=1}^{N} \alpha_i y_i = 0 \implies \sum_{i=1}^{N} \alpha_i y_i = 0$$
#
#
#
# We have $$\sum_{i=1}^{N} \alpha_i y_i = 0$$, so $$\sum_{i=1}^{N}\alpha_{i}y_{i}b = 0$$. We can eliminate the term and get:
#
# $$\mathcal{L} (\mathbf{w}, \alpha) = \frac{1}{2} \mathbf{w}^{\top}\mathbf{w} - \mathbf{w}^{\top}\sum_{i=1}^{N}\alpha_{i}y_{i} \mathbf{x}_{i} + \sum_{i=1}^{N}\alpha_{i}$$
#
#
#
# We can substitute the expressions $$\mathbf{w} = \sum_{i=1}^{N} \alpha_i y_i \mathbf{x}_i$$  back into the Lagrangian and simplify further:
#
# $$\mathcal{L} (\mathbf{w}, \alpha) = \frac{1}{2} \mathbf{w}^{\top}\sum_{i=1}^{N} \alpha_i y_i \mathbf{x}_i - \mathbf{w}^{\top}\sum_{i=1}^{N}\alpha_{i}y_{i} \mathbf{x}_{i} + \sum_{i=1}^{N}\alpha_{i}$$
#
# $$\mathcal{L} (\alpha) = \sum_{i=1}^{N}\alpha_{i} - \frac{1}{2} \mathbf{w}^{\top}\sum_{i=1}^{N} \alpha_i y_i \mathbf{x}_i$$
#
# $$\quad\quad\quad\quad\quad = \sum_{i=1}^{N}\alpha_{i} - \frac{1}{2} (\sum_{i=1}^{N} \alpha_i y_i \mathbf{x}_i)^{\top}\sum_{i=1}^{N} \alpha_i y_i \mathbf{x}_i$$
#
# $$\quad\quad\quad\quad\quad = \sum_{i=1}^{N}\alpha_{i} - \frac{1}{2} (\sum_{i=1}^{N} \alpha_i y_i \mathbf{x}_i)^{\top}\sum_{j=1}^{N} \alpha_j y_j \mathbf{x}_j$$
#
# $$\quad\quad\quad\quad\quad = \sum_{i=1}^{N}\alpha_{i} - \frac{1}{2} \sum_{i=1}^{N} \sum_{j=1}^{N}\alpha_i \alpha_j y_i y_j \mathbf{x}_i^{\top} \mathbf{x}_j$$
#
#
#
# After simplification, the Lagrangian function only depends on $$\alpha$$, and $$\mathbf{w}$$ and b are eliminated from the formulation. Finally, we got $$\mathcal{L} (\alpha)$$ by rewriting the expression in terms of inner products:
#
# $$\mathcal{L} (\alpha) = \sum_{i=1}^{N} \alpha_i - \frac{1}{2} \sum_{i=1}^{N} \sum_{j=1}^{N} \alpha_i \alpha_j y_i y_j (\mathbf{x}_i \cdot \mathbf{x}_j)$$
#
#
#
# **Dual Formation:**
# Now, we can write the dual form by maximising the Lagrangian with respect to $$\alpha$$ while subject to the constraints:
#
# $$ \max_{\alpha}  \sum_{i=1}^{N}\alpha_{i} - \frac{1}{2}\sum_{i=1}^{N}\sum_{j=1}^{N}\alpha_{i}\alpha_{j}y_{i}y_{j}(\mathbf{x}_i \cdot \mathbf{x}_j)\\$$
#
# $$\text{s.t.} \quad
#  \alpha_{i} \geq 0, i=1,2,...,N$$
#
# $$\quad \sum_{i=1}^{N}\alpha_{i}y_{i} = 0\\$$

# %% [markdown]
# ## Q2

# %% [markdown]
# ### Data Preprocessing

# %%
import cvxpy as cp
import numpy as np
import pandas as pd

# Load data
train_df = pd.read_csv('train.csv', header = None)   
test_df = pd.read_csv('test.csv', header = None)

# Split training data 
X_train = train_df.iloc[:4000,1:].values
y_train = train_df.iloc[:4000,0].values
X_valid = train_df.iloc[4000:,1:].values
y_valid = train_df.iloc[4000:,0].values

# Test data
X_test = test_df.iloc[:1500,1:].values
y_test = test_df.iloc[:1500,0].values 

# change the label set from [0,1] to [-1,1]
y_train[y_train==0] = -1
y_valid[y_valid==0] = -1
y_test[y_test==0] = -1

# %% [markdown]
# ### Solving

# %%
def svm_train_primal(data_train, label_train, regularisation_para_C):
    N,M = np.shape(X_train)
    w = cp.Variable(M)
    b = cp.Variable()
    psi = cp.Variable(N)
    
    obj = cp.Minimize(1/2 * cp.square(cp.norm(w)) + regularisation_para_C/N * cp.sum(psi))
    constraints = [cp.multiply(label_train, cp.matmul(data_train, w) + b) - 1 + psi >= 0, psi >= 0]
    
    prob = cp.Problem(obj, constraints)
    prob.solve(solver = cp.ECOS)
    
    svm_model = [w.value, b.value]
    
    return svm_model

def svm_predict_primal(data_test, label_test, svm_model):
    pred = data_test @ svm_model[0] + svm_model[1]
    test_accuracy = (pred * label_test >= 0).mean()
    return test_accuracy

# %%
svm_model = svm_train_primal(X_train, y_train, 100)

print('Sum of Weights:', np.sum(svm_model[0]))  
print('Bias:', svm_model[1])
print('Weights:', svm_model[0])

# Evaluate on validation set
print('Validation accuracy:', svm_predict_primal(X_valid, y_valid, svm_model))

# Evaluate on test set
print('Test accuracy:', svm_predict_primal(X_test, y_test, svm_model))
# Out:
# Sum of Weights: -0.1452156803361282
# Bias: 1.779813717087077
# Weights: [-2.62256248e-02 -1.14170078e-01  4.18579799e-02 -5.22845669e-02
#   7.55202946e-02 -7.49320122e-03  2.79475590e-02 -1.01836328e-02
#   5.70713692e-03  9.35180508e-04  9.63053253e-02  6.44675409e-02
#   6.85235525e-02  6.24507128e-02  1.82680413e-02 -2.39290405e-02
#  -5.77847734e-02 -4.51091289e-02 -5.51945227e-02 -2.57625230e-02
#  -2.12171400e-03  4.38334162e-02 -8.61762981e-03 -4.62127414e-02
#  -2.00072969e-02 -1.86331311e-02 -3.55418258e-03  9.42355137e-03
#  -7.37762223e-02  1.15438182e-01 -2.37146292e-02 -1.37942609e-02
#   6.08601783e-02 -2.12027178e-02  8.70484930e-02 -3.83813251e-02
#   2.25715781e-02 -5.23002670e-02  5.51304956e-02 -3.70501494e-02
#   2.71704546e-02  2.27366373e-02 -2.35837201e-02 -4.09057084e-03
#   2.74264635e-02 -2.47129605e-02  1.45876790e-01  7.26289888e-02
#   1.54886589e-02  9.83911876e-02 -3.15621084e-02  3.83273778e-02
# ...

# %% [markdown]
# ## Q3

# %%
# Using CVXPY
def svm_train_dual(data_train, label_train, regularisation_para_C):
    N,M = np.shape(X_train)
    alpha = cp.Variable(N)
    
    obj = cp.Maximize(cp.sum(alpha) - (1/2) * cp.sum_squares(data_train.T @ (cp.multiply(alpha, label_train))))
    constraints = [alpha >= 0, alpha <= regularisation_para_C / N, cp.sum(cp.multiply(alpha, label_train)) == 0]
    
    prob = cp.Problem(obj, constraints)
    prob.solve(solver = cp.ECOS)

    return alpha.value

alpha = svm_train_dual(X_train, y_train, 100)

print('Sum of All Dimensions of Alpha:', np.sum(alpha))  
print('Alpha:', alpha)
# Out:
# Sum of All Dimensions of Alpha: 7.28163240568506
# Alpha: [ 2.50000000e-02 -6.91631310e-13 -9.06563487e-13 ... -6.35096121e-13
#  -7.30265872e-13 -7.70674234e-13]

# %% [markdown]
# ## Q4

# %%
import numpy as np

def obtain_w_b(data_train, label_train, alpha, regularisation_para_C):
    N, M = data_train.shape
    
    # calculate w
    w = np.zeros(M)
    for i in range(N):
        w += alpha[i] * label_train[i] * data_train[i]
        
    # calculate b from a support vector
    support_index = np.where((alpha >= 1e-6) & (regularisation_para_C / N - alpha >= 1e-6))[0]
    first = support_index[0]
    b = label_train[first] - np.dot(w, data_train[first])
    
    return w, b

svm_model = obtain_w_b(X_train, y_train, alpha, 100)
print('Sum of w*:', np.sum(svm_model[0]))  
print('b*:', svm_model[1])
print('w*:', svm_model[0])

# Evaluate on validation set
print('Validation accuracy:', svm_predict_primal(X_valid, y_valid, svm_model))

# Evaluate on test set
print('Test accuracy:', svm_predict_primal(X_test, y_test, svm_model))
# Out:
# Sum of w*: -0.14521570328648392
# b*: 1.779813609141915
# w*: [-2.62256325e-02 -1.14170128e-01  4.18580421e-02 -5.22847589e-02
#   7.55203783e-02 -7.49321454e-03  2.79476228e-02 -1.01835769e-02
#   5.70700796e-03  9.35205087e-04  9.63053441e-02  6.44674061e-02
#   6.85236986e-02  6.24507874e-02  1.82679567e-02 -2.39292014e-02
#  -5.77846985e-02 -4.51090707e-02 -5.51944747e-02 -2.57625920e-02
#  -2.12175923e-03  4.38334082e-02 -8.61758614e-03 -4.62128963e-02
#  -2.00073103e-02 -1.86329829e-02 -3.55406632e-03  9.42359814e-03
#  -7.37762338e-02  1.15438129e-01 -2.37146346e-02 -1.37941991e-02
#   6.08602332e-02 -2.12026519e-02  8.70485036e-02 -3.83812779e-02
#   2.25715632e-02 -5.23002326e-02  5.51304801e-02 -3.70501948e-02
#   2.71703968e-02  2.27366325e-02 -2.35837248e-02 -4.09049594e-03
#   2.74264790e-02 -2.47129769e-02  1.45876933e-01  7.26288457e-02
#   1.54886312e-02  9.83912952e-02 -3.15621623e-02  3.83274597e-02
#   8.67247571e-02 -4.81607771e-02  5.38167968e-02 -4.18262695e-02
# ...

# %% [markdown]
# ## Q5

# %%
def find_support_vectors_primal(data_train, label_train, regularisation_para_C):
    support_vectors = []
    N, M = data_train.shape
    
    svm_model = svm_train_primal(data_train, label_train, regularisation_para_C)
    w, b = svm_model[0], svm_model[1]
    
    for i in range(N):
        if label_train[i] == 1:  
            if np.abs(np.dot(w, data_train[i]) + b - 1) <= 1e-6:
                support_vectors.append(data_train[i])
        if label_train[i] == -1:  
            if np.abs(np.dot(w, data_train[i]) + b + 1) <= 1e-6:
                support_vectors.append(data_train[i])
    return support_vectors

support_vectors_primal = find_support_vectors_primal(X_train, y_train, 100)
print("Support Vectors from the Primal Problem Solutions:")
support_vectors_primal
# Out:
# Support Vectors from the Primal Problem Solutions:
# [array([ 1.05, -1.79,  0.9 ,  0.68,  0.54, -1.93, -0.71, -0.18,  1.4 ,
#          0.73, -0.2 ,  1.31,  0.43, -0.94, -0.05,  0.71, -0.55,  2.26,
#         -0.27,  0.24, -0.52,  1.78,  1.46,  1.16,  0.05, -1.62, -0.76,
#          0.57, -2.01, -0.01,  0.22,  0.41,  0.11, -1.55, -0.74, -0.08,
#         -1.16, -0.52, -0.13, -0.3 , -0.27, -0.09,  1.17,  0.83, -0.39,
#         -0.23,  0.15, -1.38,  0.68,  1.01,  0.66, -0.09, -0.83, -1.22,
#          1.44,  1.19, -0.89,  1.  ,  1.66, -3.63,  0.09, -0.77,  0.28,
#         -0.23,  0.63, -0.78,  0.32,  1.6 , -0.83,  1.27,  0.84,  0.23,
#          0.98,  0.56, -0.7 , -0.15, -0.75,  0.17,  1.55, -0.98, -1.43,
#          0.95, -0.49, -0.84, -0.14, -1.11, -1.91,  0.59,  0.88, -0.76,
#          1.04, -1.61, -1.26,  2.73,  1.45,  0.01, -0.05, -0.4 ,  0.99,
#          0.89,  1.21,  0.99, -0.67, -0.5 , -0.67,  0.33,  0.68,  0.77,
# ...

# %%
len(support_vectors_primal)
# Out:
# 180

# %% [markdown]
# ## Q6

# %%
regularisation_para_C = 100
N = X_train.shape[0]
support_index = np.where((alpha > 1e-6) & (regularisation_para_C / N - alpha > 1e-6))[0]
support_vectors_dual = X_train[support_index]
print("Support Vectors from the Dual Problem Solutions:")
support_vectors_dual
# Out:
# Support Vectors from the Dual Problem Solutions:
# array([[ 1.05, -1.79,  0.9 , ...,  0.39,  0.6 , -1.66],
#        [ 0.29, -2.31, -0.4 , ...,  0.1 ,  0.06,  0.54],
#        [ 1.65,  0.32, -0.72, ..., -0.42, -1.27,  0.91],
#        ...,
#        [ 0.33, -1.  , -0.  , ...,  0.94, -0.09,  1.76],
#        [ 0.16, -1.6 ,  1.34, ...,  0.84, -0.86, -1.25],
#        [ 0.79,  1.01,  1.2 , ...,  0.85, -0.97,  0.98]])

# %%
# Experiment: Make sure that there is no vectors that are alpha_i ~ 0 and y_i(w^T X_i + b) - 1 ~ 0
flag = 0
svm_model = svm_train_primal(X_train, y_train, 100)
w, b = svm_model[0], svm_model[1]
for i in range(N):
    if abs(alpha[i]) <= 1e-6 and abs(y_train[i] * (np.dot(w, X_train[i]) + b) - 1) <= 1e-6:
        flag = 1
        print("Another Support Vector Found")
if flag == 0:
    print("No Other Support Vector Found")
# Out:
# No Other Support Vector Found

# %%
len(support_vectors_dual)
# Out:
# 182

# %% [markdown]
# ## Q7

# %%
candidate_C = [2 ** i for i in range(-10, 11, 2)]
candidate_test_accuracy = []
for C in candidate_C:
    svm_model = svm_train_primal(X_train, y_train, C)
    candidate_test_accuracy.append(svm_predict_primal(X_valid, y_valid, svm_model))
    
for i, accuracy in zip(range(-10, 11, 2), candidate_test_accuracy):
    print(f"C = 2^{i}, Accuracy = {accuracy}")
    
opt_valid_accuracy = max(candidate_test_accuracy)
opt_C_index = candidate_test_accuracy.index(opt_valid_accuracy)
opt_C = candidate_C[opt_C_index]
opt_test_accuracy = svm_predict_primal(X_test, y_test, svm_train_primal(X_train, y_train, opt_C))

print(f"Optimal C = {opt_C}, Validation Set Accuracy = {opt_valid_accuracy}, Test Set Accuracy = {opt_test_accuracy}")
# Out:
# /usr/local/lib/python3.11/site-packages/cvxpy/problems/problem.py:1387: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# C = 2^-10, Accuracy = 0.4908888888888889
# C = 2^-8, Accuracy = 0.4908888888888889
# C = 2^-6, Accuracy = 0.4908888888888889
# C = 2^-4, Accuracy = 0.9244444444444444
# C = 2^-2, Accuracy = 0.9622222222222222
# C = 2^0, Accuracy = 0.9717777777777777
# C = 2^2, Accuracy = 0.9748888888888889
# C = 2^4, Accuracy = 0.974
# C = 2^6, Accuracy = 0.9713333333333334
# C = 2^8, Accuracy = 0.966
# C = 2^10, Accuracy = 0.9626666666666667
# Optimal C = 4, Validation Set Accuracy = 0.9748888888888889, Test Set Accuracy = 0.9746666666666667

# %%
# print opt w, b
svm_model_opt = svm_train_primal(X_train, y_train, 4)
print('Sum of w:', np.sum(svm_model_opt[0]))  
print('b:', svm_model_opt[1])
print('w:', svm_model_opt[0])
# Out:
# Sum of w: -0.09799142609364914
# b: 0.9130704080137506
# w: [ 2.92272082e-03 -1.65430796e-02  2.82126032e-02 -1.33765727e-03
#   1.37609277e-02 -1.89677114e-02  8.83218909e-03 -4.04958112e-03
#  -2.61434076e-03  4.39526381e-03  1.99777531e-02  1.28434905e-03
#   4.07343098e-03 -1.70787932e-03  1.97065135e-02  1.32939194e-02
#  -6.61348644e-03 -5.87895692e-03 -5.72317723e-03 -5.11940457e-04
#   9.02793686e-03  1.03102615e-02  1.44273012e-03 -1.30167090e-02
#  -7.06611054e-03 -4.27935038e-03  3.98972266e-03  1.07836978e-02
#  -8.79275392e-03  1.93078541e-02  3.50873518e-03  9.67524989e-03
#   5.70882294e-03 -2.18854320e-03  2.52467382e-02  1.78026649e-02
#   1.33350925e-02 -3.75389679e-03  1.29424301e-02  5.19432248e-03
#  -4.64459168e-04 -8.17557382e-03 -3.06719085e-03 -4.79269297e-04
#   8.99305779e-03 -3.58108682e-04  2.99693860e-02  8.29298595e-03
#  -1.63092646e-02  2.63056707e-02  4.32643997e-03 -8.15195178e-03
#   8.37774275e-03  3.36329180e-03  8.66186181e-03  1.02324004e-03
# ...

# %% [markdown]
# ## Q8

# %%
from sklearn.metrics import accuracy_score
from sklearn.svm import LinearSVC

svm_model = LinearSVC(C = 4 / X_train.shape[0])
svm_model.fit(X_train, y_train)
y_pred = svm_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9666666666666667

# %% [markdown]
# ## Appendix

# %% [markdown]
# ## Q3 Using CVXOPT

# %%
import cvxopt
import cvxopt.solvers as solvers
import numpy as np

# Using CVXOPT
 
def svm_train_dual(data_train, label_train, regularisation_para_C):
    N, M = data_train.shape
    
    K = np.dot(data_train, data_train.T)
    
    P = cvxopt.matrix(np.outer(label_train, label_train) * K)
    q = cvxopt.matrix(-np.ones((N, 1)))
    G = cvxopt.matrix(np.vstack((np.eye(N) * (-1), np.eye(N))))
    h = cvxopt.matrix(np.hstack((np.zeros(N), np.ones(N) * (regularisation_para_C / N))))
    A = cvxopt.matrix(label_train, (1,N))
    b = cvxopt.matrix(np.zeros(1))
    
    sol = solvers.qp(P, q, G, h, A, b)
    
    alpha = np.ravel(sol['x'])
    return alpha

alpha = svm_train_dual(X_train, y_train, 100)

print('Sum of All Dimensions of Alpha:', np.sum(alpha))  
print('Alpha:', alpha)
# Out:
#      pcost       dcost       gap    pres   dres
#  0: -3.8416e+02 -2.2800e+02  4e+04  1e+02  5e-13
#  1: -2.2204e+01 -2.2367e+02  1e+03  3e+00  5e-13
#  2: -1.2704e+01 -1.3798e+02  2e+02  4e-01  7e-14
#  3: -8.2452e+00 -4.8671e+01  6e+01  1e-01  2e-14
#  4: -6.5928e+00 -2.4543e+01  3e+01  4e-02  1e-14
#  5: -5.8533e+00 -1.1273e+01  7e+00  1e-02  1e-14
#  6: -5.9382e+00 -7.9755e+00  2e+00  2e-03  1e-14
#  7: -6.1146e+00 -6.9517e+00  1e+00  7e-04  1e-14
#  8: -6.2067e+00 -6.5700e+00  4e-01  1e-04  1e-14
#  9: -6.3032e+00 -6.4094e+00  1e-01  2e-05  1e-14
# 10: -6.3347e+00 -6.3622e+00  3e-02  4e-06  1e-14
# 11: -6.3454e+00 -6.3477e+00  2e-03  1e-07  2e-14
# 12: -6.3464e+00 -6.3465e+00  2e-04  5e-09  2e-14
# 13: -6.3464e+00 -6.3464e+00  4e-06  1e-10  2e-14
# Optimal solution found.
# Sum of All Dimensions of Alpha: 7.281637057117688
# Alpha: [2.49999998e-02 1.76599916e-10 1.27338214e-10 ... 2.12327234e-10
#  2.14991999e-10 1.29691367e-10]

# %% [markdown]
# ## Q8 Finding Optimal C Using LinearSVC

# %%
candidate_C = [2 ** i for i in range(-10, 11, 2)]
candidate_test_accuracy = []
for candid in candidate_C:
    svm_model = LinearSVC(C = candid / X_train.shape[0])
    svm_model.fit(X_train, y_train)
    y_pred = svm_model.predict(X_valid)
    candidate_test_accuracy.append(accuracy_score(y_valid, y_pred))
    
for i, accuracy in zip(range(-10, 11, 2), candidate_test_accuracy):
    print(f"C = 2^{i}, Accuracy = {accuracy}")
    
opt_valid_accuracy = max(candidate_test_accuracy)
opt_C_index = candidate_test_accuracy.index(opt_valid_accuracy)
opt_C = candidate_C[opt_C_index]
svm_model = LinearSVC(C = opt_C / X_train.shape[0])
svm_model.fit(X_train, y_train)
y_pred = svm_model.predict(X_test)
opt_test_accuracy = accuracy_score(y_test, y_pred)

print(f"Optimal C = {opt_C}, Validation Set Accuracy = {opt_valid_accuracy}, Test Set Accuracy = {opt_test_accuracy}")
# Out:
# C = 2^-10, Accuracy = 0.8766666666666667
# C = 2^-8, Accuracy = 0.8948888888888888
# C = 2^-6, Accuracy = 0.9288888888888889
# C = 2^-4, Accuracy = 0.9533333333333334
# C = 2^-2, Accuracy = 0.9595555555555556
# C = 2^0, Accuracy = 0.9626666666666667
# C = 2^2, Accuracy = 0.9646666666666667
# C = 2^4, Accuracy = 0.9666666666666667
# C = 2^6, Accuracy = 0.966
# C = 2^8, Accuracy = 0.9653333333333334
# C = 2^10, Accuracy = 0.9648888888888889
# Optimal C = 16, Validation Set Accuracy = 0.9666666666666667, Test Set Accuracy = 0.968
# /usr/local/lib/python3.11/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
